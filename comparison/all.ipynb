# %%
import plumed
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # S1 S3 S6 S8

# %%
# plot free energy as a function of simulation timefor i in range(700,857,30):   
 # import fes file into pandas dataset
data1=plumed.read_as_pandas("./S1_fes_1363.dat")
data2=plumed.read_as_pandas("./S2_fes_1287.dat")
data3=plumed.read_as_pandas("./S7_fes_937.dat")
data4=plumed.read_as_pandas("./S8_fes_1672.dat")


 # plot fes
plt.plot(data1["D0"],data1["file.free"], label="S1") 
plt.plot(data2["D0"],data2["file.free"], label="S2") 
plt.plot(data3["D0"],data3["file.free"], label="S7") 
plt.plot(data4["D0"],data4["file.free"], label="S8") 

# labels
plt.xlabel("Distance (nm)")
plt.ylabel("free energy [kcal/mol]")
plt.legend(loc = 'upper left',ncol=4)
plt.legend(ncol=2)
plt.ylim([0,60])
plt.savefig('All.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_9437/1660252142.py:3: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data1=plumed.read_as_pandas("./S1_fes_1363.dat")
# /tmp/ipykernel_9437/1660252142.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data2=plumed.read_as_pandas("./S2_fes_1287.dat")
# /tmp/ipykernel_9437/1660252142.py:5: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data3=plumed.read_as_pandas("./S7_fes_937.dat")
# /tmp/ipykernel_9437/1660252142.py:6: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data4=plumed.read_as_pandas("./S8_fes_1672.dat")
# /tmp/ipykernel_9437/1660252142.py:21: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('All.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )

# %% [markdown]
# # S1

# %%
# plot free energy as a function of simulation time
for i in range(800,857,5):   
 # import fes file into pandas dataset
 data=plumed.read_as_pandas("/home/vvithurshan/Documents/Jupyter_NoteBook/JULY/Project_Funnel_1607_V1_D0/hills2/fes_"+str(i)+".dat")
 # plot fes
 plt.plot(data["D0"],data["file.free"], label=str(int(i))+" ns") 
# labels
plt.xlabel("Distance (nm)")
plt.ylabel("free energy [kcal/mol]")
plt.legend(loc = 'upper left',ncol=4)
plt.legend(ncol=2)
plt.ylim([0,30])
plt.savefig('S1.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_11337/1436894505.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Documents/Jupyter_NoteBook/JULY/Project_Funnel_1607_V1_D0/hills2/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/1436894505.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Documents/Jupyter_NoteBook/JULY/Project_Funnel_1607_V1_D0/hills2/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/1436894505.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Documents/Jupyter_NoteBook/JULY/Project_Funnel_1607_V1_D0/hills2/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/1436894505.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
# ...

# %%
# plot free energy as a function of simulation time
for i in range(2200, 2300,2):   
 # import fes file into pandas dataset
 data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
 # plot fes
 plt.plot(data["D0"],data["file.free"])#, label=str(int(i))+" ns") 
# labels
plt.xlabel("Distance (nm)")
plt.ylabel("free energy [kcal/mol]")
plt.legend(loc = 'upper left',ncol=4)
plt.legend(ncol=2)
plt.ylim([0,40])
# plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_11337/2539298108.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/2539298108.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/2539298108.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/2539298108.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# ...

# %% [markdown]
# # S6

# %%
# plot free energy as a function of simulation time
for i in range(2200, 2300,2):   
 # import fes file into pandas dataset
 data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
 # plot fes
 plt.plot(data["D0"],data["file.free"])#, label=str(int(i))+" ns") 
# labels
plt.xlabel("Distance (nm)")
plt.ylabel("free energy [kcal/mol]")
plt.legend(loc = 'upper left',ncol=4)
plt.legend(ncol=2)
plt.ylim([0,40])
plt.savefig('S6.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_11337/53058114.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/53058114.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/53058114.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/53058114.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S6/3.Meta-S6/output/HILLS_ROOT/fes_"+str(i)+".dat")
# ...

# %% [markdown]
# # S8

# %%
# plot free energy as a function of simulation time
for i in range(1200, 1267,2):   
 # import fes file into pandas dataset
 data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S8/3.Meta/Project_Aug-14-S8/output/HILLS_ROOT/fes_"+str(i)+".dat")
 # plot fes
 plt.plot(data["D0"],data["file.free"])#, label=str(int(i))+" ns") 
# labels
plt.xlabel("Distance (nm)")
plt.ylabel("free energy [kcal/mol]")
plt.legend(loc = 'upper left',ncol=4)
plt.legend(ncol=2)
plt.ylim([0,40])
plt.savefig('S8.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_11337/2085512414.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S8/3.Meta/Project_Aug-14-S8/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/2085512414.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S8/3.Meta/Project_Aug-14-S8/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/2085512414.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data=plumed.read_as_pandas("/home/vvithurshan/Desktop/Research_22/August/S8/3.Meta/Project_Aug-14-S8/output/HILLS_ROOT/fes_"+str(i)+".dat")
# /tmp/ipykernel_11337/2085512414.py:4: UserWarning: cannot load PLUMED instance, conversions will not be available
# ...
