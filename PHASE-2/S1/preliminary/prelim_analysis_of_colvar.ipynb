# %%
import plumed
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # D0

# %%
# visualize CV file
data_time=plumed.read_as_pandas("cv")
plt.plot(data_time["time"],data_time["D0"],'o', ms=1)
# x-y axis labels
plt.xlabel("Simulation time")
plt.ylabel("D0 [nm]")
ax = sns.kdeplot(data_time["D0"], shade =True,label='Do',color='black')
# Out:
# /tmp/ipykernel_5099/4098820195.py:2: UserWarning: cannot load PLUMED instance, conversions will not be available
#   data_time=plumed.read_as_pandas("cv")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5099/4098820195.py in <module>
#       1 # visualize CV file
# ----> 2 data_time=plumed.read_as_pandas("cv")
#       3 plt.plot(data_time["time"],data_time["D0"],'o', ms=1)
#       4 # x-y axis labels
#       5 plt.xlabel("Simulation time")
#
# plumed.pyx in plumed.read_as_pandas()
#
# plumed.pyx in plumed._fix_file()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cv'

# %%
import csv

# %%
data_S1 = pd.read_csv("S1.csv")
data_S6 = pd.read_csv("/home/vvithurshan/Desktop/Research_22/PHASE-2/S6/preliminary/S6.csv")
data_S8 = pd.read_csv("/home/vvithurshan/Desktop/Research_22/PHASE-2/S8/preliminary/S8.csv")

# %%
data_S1 = pd.read_csv("S1.csv")
data_S1 = data_S1['distance']
data_S1.head()
# Out:
# 0    3.633557
# 1    3.480094
# 2    3.606692
# 3    3.593140
# 4    3.408107
# Name: distance, dtype: float64

# %%
data_S6 = pd.read_csv("/home/vvithurshan/Desktop/Research_22/PHASE-2/S6/preliminary/S6.csv")
data_S6 = data_S6['distance']
data_S6.head()
# Out:
# 0    4.612836
# 1    4.608970
# 2    4.856495
# 3    4.722495
# 4    5.084767
# Name: distance, dtype: float64

# %%
data_S8 = pd.read_csv("/home/vvithurshan/Desktop/Research_22/PHASE-2/S8/preliminary/S8.csv")
data_S8 = data_S8['distance']
data_S8.head()
# Out:
# 0    3.180922
# 1    3.152896
# 2    3.329238
# 3    3.052460
# 4    3.195701
# Name: distance, dtype: float64

# %%
import csv

header = ['S1', 'S6' , 'S8']
data = [data_S1, data_S6 , data_S8]


with open('countries.csv', 'w', encoding='UTF8', newline='') as f:
    writer = csv.writer(f)

    # write the header
    writer.writerow(header)

    # write the data
    writer.writerow(data)

# %%
ax = sns.kdeplot(data_S1, shade =True,label='S1',color='g', bw_adjust=0.8, legend=True)

# %%
ax = sns.kdeplot(data_S6, shade =True,label='Do',color='b', bw_adjust=0.8)

# %%
ax = sns.kdeplot(data_S8, shade =True,label='Do',color='g', bw_adjust=0.8, alpha=0.5, linewidth=0)

# %%
ax = sns.kdeplot(data= data_S1, shade =True,label='S1',color='g', bw_adjust=0.8)
# ax = sns.kdeplot(data_S6, shade =True,label='Do',color='b', bw_adjust=0.8)
# ax = sns.kdeplot(data_S8, shade =True,label='Do',color='g', bw_adjust=0.8, alpha=0.5, linewidth=0)

# %%
print("S1 =",float(2/3/10))
# Out:
# S1 = 0.06666666666666667

# %%
print("S6 =",float(1.2/3/10))
# Out:
# S6 = 0.039999999999999994

# %%
print("S8 =",float(1.5/3/10))
# Out:
# S8 = 0.05

# %%
print("Final")
print("S1 :",0.06)
print("S6 :", 0.05)
print("S8 :",0.05)
# Out:
# Final
# S1 : 0.06
# S6 : 0.05
# S8 : 0.05

# %%
data_S1_std =[]
for i in data_S1:
    if(i < 6 and i > 2):
        data_S1_std.append(i)
        
data_S6_std =[]
for i in data_S6:
    if(i < 4.5 and i > 2):
        data_S6_std.append(i)

data_S8_std =[]
for i in data_S8:
    if(i < 4.5 and i > 2):
        data_S8_std.append(i)

# %%
print(np.std(data_S1_std)/20)
print(np.std(data_S6_std)/20)
print(np.std(data_S8_std)/20)
# Out:
# 0.029939012198219324
# 0.011004076791415409
# 0.01338777888384488

# %%
ax = sns.kdeplot(data, shade =True,label='Do',color='b', bw_adjust=0.8)

# %%
#Autocorrelation
#https://www.alpharithms.com/autocorrelation-time-series-python-432909/
#https://www.youtube.com/watch?v=fRhSGaJ4Ku8

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
data_auto = data_S1 = pd.read_csv("S1.csv")
# Calculate the ACF (via statsmodel)
plot_acf(data_auto['distance'], lags=50, alpha=0.05)
# Show the data as a plot (via matplotlib)
plt.show()

# %%
len(data_auto)
# Out:
# 25000

# %%
# CV vs Time

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')
# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(data_S1['time'][:2100],data_S1['distance'][:2100] , linewidth=2.0)

# ax.set(xlim=(0, 2250))
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
data_auto = data_S1 = pd.read_csv("S1.csv")
# Calculate the ACF (via statsmodel)
plot_acf(data_auto['distance'][:100], lags=50, alpha=0.05)
# Show the data as a plot (via matplotlib)
plt.show()
