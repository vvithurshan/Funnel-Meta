# %%
import plumed
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
import seaborn as sns
# %matplotlib inline

# %%
#Autocorrelation
#https://www.alpharithms.com/autocorrelation-time-series-python-432909/
#https://www.youtube.com/watch?v=fRhSGaJ4Ku8
#https://www.influxdata.com/blog/autocorrelation-in-time-series-data/

# %%
data_S1 = pd.read_csv("S1.csv")
data_S6 = pd.read_csv("/home/vvithurshan/Desktop/Research_22/PHASE-2/S6/preliminary/S6.csv")
data_S8 = pd.read_csv("/home/vvithurshan/Desktop/Research_22/PHASE-2/S8/preliminary/S8.csv")

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
data_auto = data_S1 = pd.read_csv("S1.csv")
# Calculate the ACF (via statsmodel)
plot_acf(data_auto['distance'], lags=50, alpha=0.05)
# Show the data as a plot (via matplotlib)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# plt.style.use('_mpl-gallery')
# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

# plot
fig, ax = plt.subplots()

ax.plot(data_S1['time'][:500],data_S1['distance'][:500] , linewidth=2.0)

# ax.set(xlim=(0, 2250))
#        ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
data_auto = data_S1 = pd.read_csv("S1.csv")
# Calculate the ACF (via statsmodel)
plot_acf(data_auto['distance'][:2000], lags=100, alpha=0.05)
# Show the data as a plot (via matplotlib)
# plt.show()
plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_46604/2314535859.py:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )

# %%
S1 = pd.read_csv("./auto_corr/COLVAR_S1_auto.csv")
print(len(S1))
S6 = pd.read_csv("./auto_corr/COLVAR_S6_auto.csv")
print(len(S6))
S8 = pd.read_csv("./auto_corr/COLVAR_S8_auto.csv")
print(len(S8))
# Out:
# 92732
# 500001
# 500001

# %%
#S1

# %%
fig, ax = plt.subplots()

ax.plot(S1['time'][:]*2,S1['distance'][:] , linewidth=2.0)

# ax.set(xlim=(0, 2250))
#        ylim=(0, 8), yticks=np.arange(1, 8))

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
data_auto = S1 = pd.read_csv("COLVAR_S1_auto.csv")
# Calculate the ACF (via statsmodel)
plot_acf(data_auto['distance'][::2], lags=120, alpha=0.05)
# Show the data as a plot (via matplotlib)
# plt.show()
plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
# Out:
# /tmp/ipykernel_8395/2974594486.py:14: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error two minor releases later
#   plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )

# %%
#S6

# %%
fig, ax = plt.subplots()

ax.plot(S6['time'][:],S6['distance'][:]*10 , linewidth=2.0)

# ax.set(xlim=(0, 2250))
#        ylim=(0, 8), yticks=np.arange(1, 8))

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
# Calculate the ACF (via statsmodel)
plot_acf(S6['distance'][:4000:1], lags=200, alpha=0.05)
# Show the data as a plot (via matplotlib)
plt.show()
# plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )

# %%
#S8

# %%
fig, ax = plt.subplots()

ax.plot(S8['time'][:],S8['distance'][:]*10 , linewidth=2.0)

# ax.set(xlim=(0, 2250))
#        ylim=(0, 8), yticks=np.arange(1, 8))

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt


# Use the Autocorrelation function
# from the statsmodel library passing
# our DataFrame object in as the data
# Note: Limiting Lags to 50
# S1 = pd.read_csv("COLVAR_S1_auto.csv")
# Calculate the ACF (via statsmodel)
plot_acf(S8['distance'][::], lags=1200, alpha=0.05)
# Show the data as a plot (via matplotlib)
plt.show()
# plt.savefig('fes.png',bbox="tight", dpi=500, transparent=False, facecolor='white' )
