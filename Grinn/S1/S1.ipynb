# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv("energies_intEnMeanTotalList.csv")

# %%
df = df.iloc[112:,1:]

# %%
x = df.iloc[0:66,0]
y = df.iloc[0:66,1]
x2 = df.iloc[66:,0]
y2 = df.iloc[66:,1]
print(len(x))
print(len(y))
# Out:
# 66
# 66

# %%
# plot
# fig, ax = plt.subplots()

plt.figure(figsize=(25,8))
plt.bar(x, y, width=1, edgecolor="white", linewidth=0.8)
plt.xticks(rotation='vertical')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.savefig('S1-0.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# plt.show()
# Out:
# /tmp/ipykernel_3928953/1695662854.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('S1-0.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))

# %%
# plot
# fig, ax = plt.subplots()

plt.figure(figsize=(25,8))
plt.bar(x2, y2, width=1, edgecolor="white", linewidth=0.8)
plt.xticks(rotation='vertical')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.savefig('S1-1.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# plt.show()
# Out:
# /tmp/ipykernel_3928953/1935943563.py:8: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "bbox" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig('S1-1.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))

# %%
list = []
for i in range(1,243):
    list.append(0)

# %%
c = 0
for i in x:
    a = int(i[4:])
    list[a] = y.iloc[c]
    c += 1

# %%
list2 = []
for i in range(1,243):
    list2.append(i)

# %%
df1 = pd.DataFrame(list2, columns=['id'])
df2 = pd.DataFrame(list, columns=['energy'])

# %%
con = pd.concat([df1,df2], axis=1)

# %%
con
# Out:
#       id  energy
# 0      1     0.0
# 1      2     0.0
# 2      3     0.0
# 3      4     0.0
# 4      5     0.0
# ..   ...     ...
# 237  238     0.0
# 238  239     0.0
# 239  240     0.0
# 240  241     0.0
# 241  242     0.0
#
# [242 rows x 2 columns]

# %%
# plot
fig, ax = plt.subplots()
x = con.iloc[:150,0]
y = con.iloc[:150,1]
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

# ax.set(x,yticks=np.arange(1, 8))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/nmrbox/0014/vvarenthirarajah/Documents/Analysis/Grinn/S1/S1.ipynb Cell 14' in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Btin.nmrbox.org/home/nmrbox/0014/vvarenthirarajah/Documents/Analysis/Grinn/S1/S1.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> x = con.iloc[:150,0]
#       <a href='vscode-notebook-cell://ssh-remote%2Btin.nmrbox.org/home/nmrbox/0014/vvarenthirarajah/Documents/Analysis/Grinn/S1/S1.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> y = con.iloc[:150,1]
# ----> <a href='vscode-notebook-cell://ssh-remote%2Btin.nmrbox.org/home/nmrbox/0014/vvarenthirarajah/Documents/Analysis/Grinn/S1/S1.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7,rotation='vertical')
# ...
