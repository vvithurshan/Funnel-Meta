# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Error.  nthreads cannot be larger than environment variable "NUMEXPR_MAX_THREADS" (64)

# %%
import numpy as np

# %%
df = pd.read_csv("energies_intEnMeanTotalList.csv")

# %%
df.columns = ['position','residues','energy']
# df['residues'] = df['residues'].str[5:]
# df['residues'] = df['residues'].str[1:]

# %%
df_p1=df[(df['position'].str.contains('SPRO1'))]
df_p2=df[(df['position'].str.contains('SALA2'))]
df_p3=df[(df['position'].str.contains('SPHE3'))]
df_p4=df[(df['position'].str.contains('SPHE4'))]

# %%
x = df_p1.iloc[:,1]
y = df_p1.iloc[:,2]
plt.figure(figsize=(25,8))
plt.bar(x, y, width=1, edgecolor="white", linewidth=0.1)
plt.xticks(rotation='vertical')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
# plt.savefig('S8-PRO-P4.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# plt.show()

# %%
x = df_p2.iloc[:,1]
y = df_p2.iloc[:,2]
plt.figure(figsize=(25,8))
plt.bar(x, y, width=1, edgecolor="white", linewidth=0.2)
plt.xticks(rotation='vertical')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.8)
# plt.savefig('S8-ALA-P3.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# plt.show()

# %%
x = df_p3.iloc[:,1]
y = df_p3.iloc[:,2]
plt.figure(figsize=(25,8))
plt.bar(x, y, width=1, edgecolor="white", linewidth=0.2)
plt.xticks(rotation='vertical')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
# plt.savefig('S8-PHE-P2.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# plt.show()

# %%
x = df_p4.iloc[:,1]
y = df_p4.iloc[:,2]
plt.figure(figsize=(25,8))
plt.bar(x, y, width=1, edgecolor="white", linewidth=0.8)
plt.xticks(rotation='vertical')
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
# plt.savefig('S8-PHE-P1.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# plt.show()

# %%
#practice

# %%
x = df_p1.iloc[:,1]
y = df_p1.iloc[:,2]
# plt.figure(figsize=(25,8))
# plt.bar(x, y, width=1, edgecolor="white", linewidth=0.1)
# plt.xticks(rotation='vertical')
# plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
# # plt.savefig('S8-PRO-P4.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# # plt.show()

x2 = df_p2.iloc[:,1]
y2 = df_p2.iloc[:,2]
# plt.figure(figsize=(25,8))
# plt.bar(x, y, width=1, edgecolor="white", linewidth=0.2)
# plt.xticks(rotation='vertical')
# plt.grid(color = 'green', linestyle = '--', linewidth = 0.8)
# plt.savefig('S8-ALA-P3.png',bbox="tight", dpi=500, transparent=False, facecolor='white')#, figsize=(80, 60))
# # plt.show()

w = 0.1
bar1 = np.arange(243)
bar2 = [i+w for i in bar1]

plt.bar(bar1, y, w)
# plt.bar(bar2, y2, w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [41], line 23
#      20 bar1 = np.arange(243)
#      21 bar2 = [i+w for i in bar1]
# ---> 23 plt.bar(bar1, y, w)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2387, in bar(x, height, width, bottom, align, data, **kwargs)
#    2383 @_copy_docstring_and_deprecators(Axes.bar)
#    2384 def bar(
#    2385         x, height, width=0.8, bottom=None, *, align='center',
#    2386         data=None, **kwargs):
# -> 2387     return gca().bar(
#    2388         x, height, width=width, bottom=bottom, align=align,
#    2389         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
# ...
